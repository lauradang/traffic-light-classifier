# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR = "/Users/lauradang/traffic-light/dataset-sdcnd-capstone/data/real_training_data"
CATEGORIES = ['green', 'yellow', 'red']

# %%
training_data = []
IMG_SIZE = 150
for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path,img))
            new_array = cv2.resize(img_array,(IMG_SIZE, IMG_SIZE))
            training_data.append([new_array, class_num])
        except Exception as e:
            pass
# Out:
# 0
# 1
# 2

# %%
print(len(training_data))
# Out:
# 642

# %%
import random

random.shuffle(training_data)

# %%
X = []
y = []

for features, label in training_data:
    X.append(features)
    y.append(label)
    
X = np.array(X) 
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Train on 513 samples, validate on 129 samples
# Epoch 1/20
# 513/513 [==============================] - 12s 24ms/sample - loss: 0.4971 - sparse_categorical_accuracy: 0.7797 - val_loss: 0.3913 - val_sparse_categorical_accuracy: 0.7519
# Epoch 2/20
# 513/513 [==============================] - 12s 23ms/sample - loss: 0.4588 - sparse_categorical_accuracy: 0.7817 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.7519
# Epoch 3/20
# 513/513 [==============================] - 12s 23ms/sample - loss: 0.4534 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.3813 - val_sparse_categorical_accuracy: 0.7519
# Epoch 4/20
# 513/513 [==============================] - 13s 26ms/sample - loss: 0.3779 - sparse_categorical_accuracy: 0.7953 - val_loss: 0.3283 - val_sparse_categorical_accuracy: 0.7442
# Epoch 5/20
# 513/513 [==============================] - 17s 32ms/sample - loss: 0.4053 - sparse_categorical_accuracy: 0.7973 - val_loss: 0.3814 - val_sparse_categorical_accuracy: 0.7829
# Epoch 6/20
# 513/513 [==============================] - 15s 30ms/sample - loss: 0.3682 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8140
# Epoch 7/20
# 513/513 [==============================] - 14s 27ms/sample - loss: 0.3476 - sparse_categorical_accuracy: 0.8421 - val_loss: 0.2643 - val_sparse_categorical_accuracy: 0.9535
# Epoch 8/20
# 513/513 [==============================] - 11s 21ms/sample - loss: 0.2708 - sparse_categorical_accuracy: 0.8596 - val_loss: 0.2626 - val_sparse_categorical_accuracy: 0.9767
# Epoch 9/20
# 513/513 [==============================] - 11s 21ms/sample - loss: 0.2749 - sparse_categorical_accuracy: 0.8694 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9690
# Epoch 10/20
# 513/513 [==============================] - 11s 22ms/sample - loss: 0.2155 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.1690 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/20
# 513/513 [==============================] - 10s 20ms/sample - loss: 0.2307 - sparse_categorical_accuracy: 0.8752 - val_loss: 0.1185 - val_sparse_categorical_accuracy: 0.9922
# Epoch 12/20
# 513/513 [==============================] - 11s 21ms/sample - loss: 0.1985 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/20
# 513/513 [==============================] - 13s 26ms/sample - loss: 0.1945 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.0540 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/20
# 513/513 [==============================] - 10s 20ms/sample - loss: 0.1759 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/20
# 513/513 [==============================] - 10s 20ms/sample - loss: 0.1429 - sparse_categorical_accuracy: 0.9279 - val_loss: 0.0409 - val_sparse_categorical_accuracy: 0.9922
# Epoch 16/20
# 513/513 [==============================] - 12s 22ms/sample - loss: 0.1534 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.0496 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/20
# 513/513 [==============================] - 11s 22ms/sample - loss: 0.1519 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9922
# Epoch 18/20
# 513/513 [==============================] - 15s 29ms/sample - loss: 0.1342 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.0358 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/20
# 513/513 [==============================] - 12s 23ms/sample - loss: 0.1331 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/20
# 513/513 [==============================] - 11s 21ms/sample - loss: 0.2132 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.1035 - val_sparse_categorical_accuracy: 0.9845

# %%
import cv2

def prepare(filepath):
    IMG_SIZE = 150
    img_array = cv2.imread(filepath)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    new_array = np.expand_dims(new_array, axis=0)
    return new_array

# prepare("/Users/lauradang/Downloads/red.jpeg")
prediction = model.predict([prepare("/Users/lauradang/Downloads/greenn.jpg")])
print(prediction)
# Out:
# [[9.999471e-01 9.236754e-08 5.281319e-05]]

# %%
model.evaluate(X_test, y_test)
# Out:
# 129/129 [==============================] - 1s 7ms/sample - loss: 0.1035 - sparse_categorical_accuracy: 0.9845
# [0.10346291601195816, 0.9844961]

# %%
# CATEGORIES = ['green', 'yellow', 'red']
predictions = model.predict(X_test)
np.argmax(predictions[39])
# Out:
# 0

# %%
plt.imshow(X_test[38])
plt.show()
